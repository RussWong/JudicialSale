# %%
import sys
sys.path.append('/home/zhangjianquan/anaconda3/lib/python3.7/site-packages/')

# %%
sys.path.append('./module/')
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from pylab import mpl

# %%
from predict_preprocess import predict_preprocess
from predict_qualified import predict_qualified
from predict_encoding import predict_encoding
from predict_feature import predict_feature
from predict_model import predict_model
from predict_prediction import predict_prediction 
from predict_analysis import predict_analysis

# %%
input_path = '../../../Data/Price_System/Price_Predict/raw/house/used_house_data_test.csv'
output_path = '../../../Data/Price_System/Price_Predict/preprocess/house/used_house_data_test_preprocess.csv'
data_preprocess, cols = predict_preprocess(input_path=input_path, 
                                     output_path=output_path,
                                     is_need=1)
data_preprocess
# Out:
# 经纬度转换
# 经纬度转换开始
# 转换后数据规格：(100, 27)
# 耗时：17.0941
# 经纬度转换结束
#    House_Type  Final_Price  Transaction_Cycle  Num_Price_Adjustment  Num_Look  \
# 0        1室1厅        218.0              149.0                     1         4
# 1        3室2厅       1620.0                8.0                     0         4
# 2        2室1厅        368.0               43.0                     1         1
# 3        2室2厅        368.0              105.0                     1        18
# 4        2室2厅        289.0              108.0                     1         0
# ..        ...          ...                ...                   ...       ...
# 95       2室1厅        220.0              354.0                     1         4
# 96       3室2厅        878.0               69.0                     1         0
# 97       2室2厅        371.0               48.0                     1         1
# 98       3室2厅        850.0               68.0                     1         4
# 99       2室2厅        550.0               76.0                     1         1
#
#     Attention  Num_Browse Floor  Construction_Area Unit_Structure  ...  \
# 0           9      1565.0     中               46.0            NaN  ...
# 1           8       252.0     中              150.0            NaN  ...
# 2           0         NaN     低               59.0             平层  ...
# 3         167      6048.0     低               89.0             平层  ...
# 4          25      2956.0     高               80.0             平层  ...
# ..        ...         ...   ...                ...            ...  ...
# 95         37      5355.0     低               66.0             平层  ...
# 96         11      1099.0     低              132.0            NaN  ...
# 97         19      1446.0     高               77.0             平层  ...
# 98          1       592.0     低              129.0             平层  ...
# 99          5       265.0     低              100.0             平层  ...
#
#    Elevator Trading_Authority  Housing_Purposes House_Ownership  \
# 0         有             动迁安置房              普通住宅             非共有
# 1         有               商品房              普通住宅              共有
# 2         无               商品房              普通住宅             非共有
# 3         有               商品房              普通住宅             NaN
# 4         有             动迁安置房              普通住宅              共有
# ..      ...               ...               ...             ...
# 95        无               商品房              普通住宅              共有
# 96        有               商品房              普通住宅             非共有
# 97        有               商品房              普通住宅             非共有
# 98        有               商品房              普通住宅              共有
# 99        无               商品房              普通住宅             非共有
#
#    Year_Of_Housing Storey  Ladder Household   Longitude   Latitude
# 0              NaN   28.0     1.0       6.0  121.514616  31.133690
# 1              NaN   32.0     2.0       2.0  121.545452  31.234944
# 2              NaN    6.0     1.0       4.0  121.504486  31.187161
# 3              NaN   18.0     2.0       4.0  121.596303  31.122068
# 4              NaN   11.0     1.0       4.0  116.632891  40.329616
# ..             ...    ...     ...       ...         ...        ...
# 95             NaN    6.0     1.0       2.0  121.407487  31.074013
# 96             NaN   18.0     2.0       4.0  121.371859  31.148492
# 97             NaN   28.0     1.0       2.0  121.387241  31.030584
# 98             NaN   11.0     1.0       2.0  121.341557  31.159538
# 99             NaN    4.0     1.0       2.0  121.500610  31.110415
#
# [100 rows x 27 columns]

# %%
# cols
# Out:
# {'num': ['Final_Price',
#   'Transaction_Cycle',
#   'Num_Price_Adjustment',
#   'Num_Look',
#   'Attention',
#   'Num_Browse',
#   'Construction_Area',
#   'Age',
#   'Storey',
#   'Ladder',
#   'Household',
#   'Year_Of_Housing',
#   'Property_Rights_Time',
#   'Longitude',
#   'Latitude'],
#  'str': ['Renovation',
#   'Trading_Authority',
#   'Elevator',
#   'Housing_Purposes',
#   'Type_Structure',
#   'Oriented',
#   'Floor',
#   'House_Type',
#   'House_Ownership',
#   'Ladder_Ratio',
#   'Unit_Structure',
#   'Construction_struct']}

# %%
mpl.rcParams['font.sans-serif'] = ['SimHei']

input_path =  '../../../Data/Price_System/Price_Predict/preprocess/house/used_house_data_test_preprocess.csv'
output_path = '../../../Data/Price_System/Price_Predict/qualified/house/used_house_data_test_qualified.csv'
docs_path = '../../../docs/Price_System/Price_Predict/used_house_data_test/'
data_qualified = predict_qualified(input_path=input_path, 
                                   output_path=output_path,
                                   docs_path=docs_path,
                                   name_of_target='Final_Price', cols=cols)
data_qualified
# Out:
# 数据去重开始
# 去重后数据规格：(100, 27)
# 数据去重结束
# 去除了缺失率超过40 % 的特征:
# Property_Rights_Time
# Year_Of_Housing
# 数值型数据EM插补开始,总数据量：100
# 数值型数据EM插补完成，耗时0秒
# 非数值型数据EM插补开始,总数据量：100
# 分类变量预编码完成，开始数据插值
# 分类变量插值与反编码完成，共耗时0秒
# 异常检测开始
# All-NaN slice encountered
# All-NaN slice encountered
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Iteration num: 1
# =========异常点作图========
# 异常检测数： 15
# 异常检测后数据规格：(100, 14)
# 耗时：11.8732
# 异常检测结束
#    House_Type  Final_Price  Transaction_Cycle  Num_Price_Adjustment  Num_Look  \
# 0        1室1厅        218.0           0.857895                   0.0      0.25
# 1        2室1厅        368.0          -0.257895                   0.0     -0.50
# 2        3室2厅        775.0           0.942105                   0.0     -0.25
# 3        1室1厅        219.0           5.415789                   0.0     -0.75
# 4        3室2厅        331.0          -0.426316                   0.0     -0.50
# ..        ...          ...                ...                   ...       ...
# 80       1室1厅        250.0          -0.605263                   0.0      0.50
# 81       2室1厅        220.0           3.015789                   0.0      0.25
# 82       2室2厅        371.0          -0.205263                   0.0     -0.50
# 83       3室2厅        850.0           0.005263                   0.0      0.25
# 84       2室2厅        550.0           0.089474                   0.0     -0.50
#
#     Attention  Num_Browse Floor  Construction_Area Unit_Structure  ...  \
# 0   -0.467153   -0.069801     中          -0.598802             平层  ...
# 1   -0.729927   -0.171325     低          -0.287425             平层  ...
# 2    0.642336    1.010996     高           1.365269             跃层  ...
# 3    0.934307    0.831554     低          -0.526946             平层  ...
# 4   -0.204380   -0.191235     中           1.269461             平层  ...
# ..        ...         ...   ...                ...            ...  ...
# 80  -0.671533   -0.542470     中          -0.502994             平层  ...
# 81   0.350365    1.138167     低          -0.119760             平层  ...
# 82  -0.175182   -0.107729     高           0.143713             平层  ...
# 83  -0.700730   -0.379920     低           1.389222             平层  ...
# 84  -0.583942   -0.484143     低           0.694611             平层  ...
#
#    Ladder_Ratio Elevator  Trading_Authority Housing_Purposes House_Ownership  \
# 0          一梯六户        有              动迁安置房             普通住宅             非共有
# 1          一梯四户        无                商品房             普通住宅             非共有
# 2          一梯两户        有                商品房             普通住宅              共有
# 3          一梯两户        无                商品房             普通住宅              共有
# 4          一梯两户        有                商品房             普通住宅              共有
# ..          ...      ...                ...              ...             ...
# 80         一梯两户        无                商品房             普通住宅             非共有
# 81         一梯两户        无                商品房             普通住宅              共有
# 82         一梯两户        有                商品房             普通住宅             非共有
# 83         一梯两户        有                商品房             普通住宅              共有
# 84         一梯两户        无                商品房             普通住宅             非共有
#
#       Storey Ladder Household Longitude  Latitude
# 0   3.666667    0.0       2.0  0.000879 -0.309423
# 1   0.000000    0.0       1.0 -0.060338  0.259002
# 2   0.833333    0.0       0.0  1.700527 -1.848563
# 3   0.000000    0.0       0.0  0.966680  1.257378
# 4   1.000000    0.0       0.0  1.151992  0.346396
# ..       ...    ...       ...       ...       ...
# 80  0.000000    0.0       0.0 -0.653156 -0.223018
# 81  0.000000    0.0       0.0 -0.646515 -0.943820
# 82  3.666667    0.0       0.0 -0.768864 -1.405493
# 83  0.833333    0.0       0.0 -1.044938 -0.034645
# 84 -0.333333    0.0       0.0 -0.083761 -0.556848
#
# [85 rows x 25 columns]

# %%
input_path='../../../Data/Price_System/Price_Predict/qualified/house/used_house_data_test_qualified.csv'
output_path='../../../Data/Price_System/Price_Predict/encoding/house/used_house_data_test_encoding.csv'
data_encoding = predict_encoding(input_path=input_path,
                                 output_path=output_path,
                                 cols=cols,
                                 name_of_target='Final_Price',
                                 type_of_encoding='target')
data_encoding
# Out:
# 数据编码开始
# 编码后数据规格：(85, 25)
# 耗时：0.0586
# 数据编码结束
#     House_Type  Final_Price  Transaction_Cycle  Num_Price_Adjustment  \
# 0   316.853667        218.0           0.857895                   0.0
# 1   320.511213        368.0          -0.257895                   0.0
# 2   331.169094        775.0           0.942105                   0.0
# 3   316.853667        219.0           5.415789                   0.0
# 4   331.169094        331.0          -0.426316                   0.0
# ..         ...          ...                ...                   ...
# 80  316.853667        250.0          -0.605263                   0.0
# 81  320.511213        220.0           3.015789                   0.0
# 82  327.347627        371.0          -0.205263                   0.0
# 83  331.169094        850.0           0.005263                   0.0
# 84  327.347627        550.0           0.089474                   0.0
#
#     Num_Look  Attention  Num_Browse       Floor  Construction_Area  \
# 0       0.25  -0.467153   -0.069801  320.728232          -0.598802
# 1      -0.50  -0.729927   -0.171325  324.143338          -0.287425
# 2      -0.25   0.642336    1.010996  325.458606           1.365269
# 3      -0.75   0.934307    0.831554  324.143338          -0.526946
# 4      -0.50  -0.204380   -0.191235  320.728232           1.269461
# ..       ...        ...         ...         ...                ...
# 80      0.50  -0.671533   -0.542470  320.728232          -0.502994
# 81      0.25   0.350365    1.138167  324.143338          -0.119760
# 82     -0.50  -0.175182   -0.107729  325.458606           0.143713
# 83      0.25  -0.700730   -0.379920  324.143338           1.389222
# 84     -0.50  -0.583942   -0.484143  324.143338           0.694611
#
#     Unit_Structure  ...  Ladder_Ratio    Elevator  Trading_Authority  \
# 0       321.691833  ...    323.085011  328.514074         321.568691
# 1       321.691833  ...    317.490872  318.823366         325.362303
# 2       324.935509  ...    328.475966  328.514074         325.362303
# 3       321.691833  ...    328.475966  318.823366         325.362303
# 4       321.691833  ...    328.475966  328.514074         325.362303
# ..             ...  ...           ...         ...                ...
# 80      321.691833  ...    328.475966  318.823366         325.362303
# 81      321.691833  ...    328.475966  318.823366         325.362303
# 82      321.691833  ...    328.475966  328.514074         325.362303
# 83      321.691833  ...    328.475966  328.514074         325.362303
# 84      321.691833  ...    328.475966  318.823366         325.362303
#
#     Housing_Purposes  House_Ownership    Storey  Ladder  Household  Longitude  \
# 0         323.435294       318.840901  3.666667     0.0        2.0   0.000879
# 1         323.435294       318.840901  0.000000     0.0        1.0  -0.060338
# 2         323.435294       328.016292  0.833333     0.0        0.0   1.700527
# 3         323.435294       328.016292  0.000000     0.0        0.0   0.966680
# 4         323.435294       328.016292  1.000000     0.0        0.0   1.151992
# ..               ...              ...       ...     ...        ...        ...
# 80        323.435294       318.840901  0.000000     0.0        0.0  -0.653156
# 81        323.435294       328.016292  0.000000     0.0        0.0  -0.646515
# 82        323.435294       318.840901  3.666667     0.0        0.0  -0.768864
# 83        323.435294       328.016292  0.833333     0.0        0.0  -1.044938
# 84        323.435294       318.840901 -0.333333     0.0        0.0  -0.083761
#
#     Latitude
# 0  -0.309423
# 1   0.259002
# 2  -1.848563
# 3   1.257378
# 4   0.346396
# ..       ...
# 80 -0.223018
# 81 -0.943820
# 82 -1.405493
# 83 -0.034645
# 84 -0.556848
#
# [85 rows x 25 columns]

# %%
# data_encoding.isnull().sum()
# Out:
# House_Type              0
# Final_Price             0
# Transaction_Cycle       0
# Num_Price_Adjustment    0
# Num_Look                0
# Attention               0
# Num_Browse              0
# Floor                   0
# Construction_Area       0
# Unit_Structure          0
# Type_Structure          0
# Oriented                0
# Age                     0
# Renovation              0
# Construction_struct     0
# Ladder_Ratio            0
# Elevator                0
# Trading_Authority       0
# Housing_Purposes        0
# House_Ownership         0
# Storey                  0
# Ladder                  0
# Household               0
# Longitude               0
# Latitude                0
# dtype: int64

# %%
input_path='../../../Data/Price_System/Price_Predict/encoding/house/used_house_data_test_encoding.csv'
output_path='../../../Data/Price_System/Price_Predict/feature/house/used_house_data_test_feature.csv'
data_feature = predict_feature(input_path=input_path,
                               output_path=output_path,
                               num_of_feature=15, name_of_target='Final_Price')
data_feature
# Out:
#     House_Type  Final_Price  Transaction_Cycle  Num_Look  Attention  \
# 0   316.853667        218.0           0.857895      0.25  -0.467153
# 1   320.511213        368.0          -0.257895     -0.50  -0.729927
# 2   331.169094        775.0           0.942105     -0.25   0.642336
# 3   316.853667        219.0           5.415789     -0.75   0.934307
# 4   331.169094        331.0          -0.426316     -0.50  -0.204380
# ..         ...          ...                ...       ...        ...
# 80  316.853667        250.0          -0.605263      0.50  -0.671533
# 81  320.511213        220.0           3.015789      0.25   0.350365
# 82  327.347627        371.0          -0.205263     -0.50  -0.175182
# 83  331.169094        850.0           0.005263      0.25  -0.700730
# 84  327.347627        550.0           0.089474     -0.50  -0.583942
#
#          Floor  Construction_Area  Unit_Structure    Oriented  Renovation  \
# 0   320.728232          -0.598802      321.691833  320.526618  322.556001
# 1   324.143338          -0.287425      321.691833  320.526618  328.295174
# 2   325.458606           1.365269      324.935509  320.526618  321.166942
# 3   324.143338          -0.526946      321.691833  320.526618  328.295174
# 4   320.728232           1.269461      321.691833  320.526618  322.556001
# ..         ...                ...             ...         ...         ...
# 80  320.728232          -0.502994      321.691833  320.526618  321.166942
# 81  324.143338          -0.119760      321.691833  320.526618  321.444913
# 82  325.458606           0.143713      321.691833  320.526618  322.556001
# 83  324.143338           1.389222      321.691833  320.526618  328.295174
# 84  324.143338           0.694611      321.691833  326.159830  328.295174
#
#     Construction_struct  Ladder_Ratio    Elevator  Trading_Authority  \
# 0            330.294980    323.085011  328.514074         321.568691
# 1            316.635431    317.490872  318.823366         325.362303
# 2            330.294980    328.475966  328.514074         325.362303
# 3            330.294980    328.475966  318.823366         325.362303
# 4            330.294980    328.475966  328.514074         325.362303
# ..                  ...           ...         ...                ...
# 80           316.635431    328.475966  318.823366         325.362303
# 81           316.635431    328.475966  318.823366         325.362303
# 82           330.294980    328.475966  328.514074         325.362303
# 83           330.294980    328.475966  328.514074         325.362303
# 84           330.294980    328.475966  318.823366         325.362303
#
#     Longitude  Latitude
# 0    0.000879 -0.309423
# 1   -0.060338  0.259002
# 2    1.700527 -1.848563
# 3    0.966680  1.257378
# 4    1.151992  0.346396
# ..        ...       ...
# 80  -0.653156 -0.223018
# 81  -0.646515 -0.943820
# 82  -0.768864 -1.405493
# 83  -1.044938 -0.034645
# 84  -0.083761 -0.556848
#
# [85 rows x 16 columns]

# %%
input_path = '../../../Data/Price_System/Price_Predict/feature/house/used_house_data_test_feature.csv'
model_path = '../../../output/Price_System/Price_Predict/model/price_predict_test_bagging.pkl'
train, test_result, train_X, test_X, test_y =  predict_model(input_path=input_path,
                                                             model_path = model_path,                                                             
                                                             name_of_model='bagging',
                                                             name_of_target='Final_Price')
train
# Out:
# BaggingRegressor(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                  max_features=1.0, max_samples=1.0, n_estimators=10,
#                  n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                  warm_start=False)

# %%
train_X.to_csv('../../../output/Price_System/Price_Predict/results/bagging_test_train_X.csv' ,index=False)
train_X
# Out:
#     House_Type  Transaction_Cycle  Num_Look  Attention       Floor  \
# 0   316.853667           0.857895      0.25  -0.467153  320.728232
# 1   320.511213          -0.257895     -0.50  -0.729927  324.143338
# 2   331.169094           0.942105     -0.25   0.642336  325.458606
# 3   316.853667           5.415789     -0.75   0.934307  324.143338
# 4   331.169094          -0.426316     -0.50  -0.204380  320.728232
# ..         ...                ...       ...        ...         ...
# 63  316.853667          -0.500000     -0.25  -0.729927  324.143338
# 64  331.169094           0.647368     -0.75  -0.029197  324.143338
# 65  320.511213          -0.373684      0.25  -0.379562  324.143338
# 66  320.511213           2.542105     -0.25   0.437956  325.458606
# 67  327.347627          -0.615789     -0.50  -0.700730  324.143338
#
#     Construction_Area  Unit_Structure    Oriented  Renovation  \
# 0           -0.598802      321.691833  320.526618  322.556001
# 1           -0.287425      321.691833  320.526618  328.295174
# 2            1.365269      324.935509  320.526618  321.166942
# 3           -0.526946      321.691833  320.526618  328.295174
# 4            1.269461      321.691833  320.526618  322.556001
# ..                ...             ...         ...         ...
# 63          -0.886228      321.691833  320.526618  321.444913
# 64           1.485030      321.691833  326.159830  321.166942
# 65          -0.479042      321.691833  320.526618  328.295174
# 66          -0.167665      321.691833  320.526618  328.295174
# 67           0.383234      321.691833  320.526618  321.166942
#
#     Construction_struct  Ladder_Ratio    Elevator  Trading_Authority  \
# 0            330.294980    323.085011  328.514074         321.568691
# 1            316.635431    317.490872  318.823366         325.362303
# 2            330.294980    328.475966  328.514074         325.362303
# 3            330.294980    328.475966  318.823366         325.362303
# 4            330.294980    328.475966  328.514074         325.362303
# ..                  ...           ...         ...                ...
# 63           316.635431    317.490872  318.823366         325.362303
# 64           330.294980    328.475966  318.823366         325.362303
# 65           316.635431    328.475966  318.823366         325.362303
# 66           316.635431    328.475966  318.823366         325.362303
# 67           330.294980    328.475966  318.823366         325.362303
#
#     Longitude  Latitude
# 0    0.000879 -0.309423
# 1   -0.060338  0.259002
# 2    1.700527 -1.848563
# 3    0.966680  1.257378
# 4    1.151992  0.346396
# ..        ...       ...
# 63  -0.641698 -0.007867
# 64  -0.601705 -1.528095
# 65  -0.638181 -1.542127
# 66  -0.659236 -0.020942
# 67  -0.247807 -1.271379
#
# [68 rows x 15 columns]

# %%
model_path = '../../../output/Price_System/Price_Predict/model/price_predict_test_bagging.pkl'
data_path = '../../../Data/Price_System/Price_Predict/feature/house/used_house_data_test_feature.csv'
result = predict_prediction(model_path=model_path,
                            data_path=data_path,
                            name_of_target='Final_Price')
result
# Out:
# array([213.9, 379.7, 630. , 241.8, 428.2, 396.3, 262.5, 191.9, 277.7,
#        421.6, 219.3, 353.1, 454.1, 245.8, 229.3, 483.5, 277.2, 213.6,
#        298.1, 234.4, 217.8, 336.8, 298.4, 142.6, 291.7, 460.2, 240.4,
#        315.3, 276.6, 365.8, 242.9, 384.2, 641.1, 289. , 223.2, 201.6,
#        432.5, 244.8, 201.9, 334.2, 254.8, 229.6, 108.1, 202.9, 421.5,
#        308.3, 213.7, 354.8, 291. , 766.6, 450.2, 249.5, 218.5, 608. ,
#        572.8, 226. , 323.8, 210.9, 285.2, 227. , 262.7, 342.8, 392.4,
#        217. , 442.4, 186.4, 356.6, 298.2, 349.7, 246.1, 254.7, 310.5,
#        576.7, 560.8, 531.8, 258.5, 262. , 240.9, 209.1, 317.3, 269.7,
#        264.7, 320.3, 565.9, 486.4])

# %%
name_of_model = 'bagging'
model_path = '../../../output/Price_System/Price_Predict/model/price_predict_bagging.pkl'
data_path = '../../../output/Price_System/Price_Predict/results/bagging_test_train_X.csv'
output_path = '../../../output/Price_System/Price_Predict/analysis/bagging_test_shap.png'
predict_analysis(model_path=model_path,
                 name_of_model=name_of_model,
                 data_path=data_path,
                 output_path=output_path)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=68.0), HTML(value='')))

# %%
input_path = '../../../Data/Price_System/Price_Predict/feature/house/used_house_data_test_feature.csv'
model_path = '../../../output/Price_System/Price_Predict/model/price_predict_test_xgboost.pkl'
train, test_result, train_X, test_X, test_y =  predict_model(input_path=input_path,
                                                             model_path = model_path,                                                             
                                                             name_of_model='xgboost',
                                                             name_of_target='Final_Price')
train
# Out:
# XGBRegressor(alpha=0, base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eta=0.3, gamma=0,
#              gpu_id=-1, importance_type='gain', interaction_constraints=None,
#              lambda_=1, learning_rate=0.300000012, max_bin=256,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints=None, n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, objective='reg:squarederror', random_state=0,
#              refresh_leaf=1, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              sketch_eps=0.03, ...)

# %%
train_X.to_csv('../../../output/Price_System/Price_Predict/results/xgboost_test_train_X.csv',index=False)
train_X
# Out:
#     House_Type  Transaction_Cycle  Num_Look  Attention       Floor  \
# 0   316.853667           0.857895      0.25  -0.467153  320.728232
# 1   320.511213          -0.257895     -0.50  -0.729927  324.143338
# 2   331.169094           0.942105     -0.25   0.642336  325.458606
# 3   316.853667           5.415789     -0.75   0.934307  324.143338
# 4   331.169094          -0.426316     -0.50  -0.204380  320.728232
# ..         ...                ...       ...        ...         ...
# 63  316.853667          -0.500000     -0.25  -0.729927  324.143338
# 64  331.169094           0.647368     -0.75  -0.029197  324.143338
# 65  320.511213          -0.373684      0.25  -0.379562  324.143338
# 66  320.511213           2.542105     -0.25   0.437956  325.458606
# 67  327.347627          -0.615789     -0.50  -0.700730  324.143338
#
#     Construction_Area  Unit_Structure    Oriented  Renovation  \
# 0           -0.598802      321.691833  320.526618  322.556001
# 1           -0.287425      321.691833  320.526618  328.295174
# 2            1.365269      324.935509  320.526618  321.166942
# 3           -0.526946      321.691833  320.526618  328.295174
# 4            1.269461      321.691833  320.526618  322.556001
# ..                ...             ...         ...         ...
# 63          -0.886228      321.691833  320.526618  321.444913
# 64           1.485030      321.691833  326.159830  321.166942
# 65          -0.479042      321.691833  320.526618  328.295174
# 66          -0.167665      321.691833  320.526618  328.295174
# 67           0.383234      321.691833  320.526618  321.166942
#
#     Construction_struct  Ladder_Ratio    Elevator  Trading_Authority  \
# 0            330.294980    323.085011  328.514074         321.568691
# 1            316.635431    317.490872  318.823366         325.362303
# 2            330.294980    328.475966  328.514074         325.362303
# 3            330.294980    328.475966  318.823366         325.362303
# 4            330.294980    328.475966  328.514074         325.362303
# ..                  ...           ...         ...                ...
# 63           316.635431    317.490872  318.823366         325.362303
# 64           330.294980    328.475966  318.823366         325.362303
# 65           316.635431    328.475966  318.823366         325.362303
# 66           316.635431    328.475966  318.823366         325.362303
# 67           330.294980    328.475966  318.823366         325.362303
#
#     Longitude  Latitude
# 0    0.000879 -0.309423
# 1   -0.060338  0.259002
# 2    1.700527 -1.848563
# 3    0.966680  1.257378
# 4    1.151992  0.346396
# ..        ...       ...
# 63  -0.641698 -0.007867
# 64  -0.601705 -1.528095
# 65  -0.638181 -1.542127
# 66  -0.659236 -0.020942
# 67  -0.247807 -1.271379
#
# [68 rows x 15 columns]

# %%
name_of_model = 'xgboost'
model_path = '../../../output/Price_System/Price_Predict/model/price_predict_test_xgboost.pkl'
data_path = '../../../output/Price_System/Price_Predict/results/xgboost_test_train_X.csv'
output_path = '../../../output/Price_System/Price_Predict/analysis/xgboost_test_shap.png'
predict_analysis(model_path=model_path,
                 name_of_model=name_of_model,
                 data_path=data_path,
                 output_path=output_path)
