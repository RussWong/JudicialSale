# %%
import sys
sys.path.append('/home/zhangjianquan/anaconda3/lib/python3.7/site-packages/')

# %%
sys.path.append('./module/')
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from pylab import mpl

# %%
from predict_preprocess import predict_preprocess
from predict_qualified import predict_qualified
from predict_encoding import predict_encoding
from predict_feature import predict_feature
from predict_model import predict_model
from predict_prediction import predict_prediction 
from predict_analysis import predict_analysis

# %%
input_path = '../../../Data/Price_System/Price_Predict/raw/house/used_house_data_test.csv'
output_path = '../../../Data/Price_System/Price_Predict/preprocess/house/used_house_data_test_preprocess.csv'
data_preprocess, cols = predict_preprocess(input_path=input_path, 
                                     output_path=output_path,
                                     is_need=1)
data_preprocess
# Out:
# ==== 经纬度转换 ====
# 经纬度转换开始
# 转换后数据规格：(100, 27)
# 耗时：34.1223
# 经纬度转换结束
#    House_Type  Final_Price  Transaction_Cycle  Num_Price_Adjustment  Num_Look  \
# 0        1室1厅        218.0              149.0                     1         4
# 1        3室2厅       1620.0                8.0                     0         4
# 2        2室1厅        368.0               43.0                     1         1
# 3        2室2厅        368.0              105.0                     1        18
# 4        2室2厅        289.0              108.0                     1         0
# ..        ...          ...                ...                   ...       ...
# 95       2室1厅        220.0              354.0                     1         4
# 96       3室2厅        878.0               69.0                     1         0
# 97       2室2厅        371.0               48.0                     1         1
# 98       3室2厅        850.0               68.0                     1         4
# 99       2室2厅        550.0               76.0                     1         1
#
#     Attention  Num_Browse Floor  Construction_Area Unit_Structure  ...  \
# 0           9      1565.0     中               46.0            NaN  ...
# 1           8       252.0     中              150.0            NaN  ...
# 2           0         NaN     低               59.0             平层  ...
# 3         167      6048.0     低               89.0             平层  ...
# 4          25      2956.0     高               80.0             平层  ...
# ..        ...         ...   ...                ...            ...  ...
# 95         37      5355.0     低               66.0             平层  ...
# 96         11      1099.0     低              132.0            NaN  ...
# 97         19      1446.0     高               77.0             平层  ...
# 98          1       592.0     低              129.0             平层  ...
# 99          5       265.0     低              100.0             平层  ...
#
#    Elevator Trading_Authority  Housing_Purposes House_Ownership  \
# 0         有             动迁安置房              普通住宅             非共有
# 1         有               商品房              普通住宅              共有
# 2         无               商品房              普通住宅             非共有
# 3         有               商品房              普通住宅             NaN
# 4         有             动迁安置房              普通住宅              共有
# ..      ...               ...               ...             ...
# 95        无               商品房              普通住宅              共有
# 96        有               商品房              普通住宅             非共有
# 97        有               商品房              普通住宅             非共有
# 98        有               商品房              普通住宅              共有
# 99        无               商品房              普通住宅             非共有
#
#    Year_Of_Housing Storey  Ladder Household   Longitude   Latitude
# 0              NaN   28.0     1.0       6.0  121.514616  31.133690
# 1              NaN   32.0     2.0       2.0  121.545452  31.234944
# 2              NaN    6.0     1.0       4.0  121.504486  31.187161
# 3              NaN   18.0     2.0       4.0  121.596303  31.122068
# 4              NaN   11.0     1.0       4.0  116.632891  40.329616
# ..             ...    ...     ...       ...         ...        ...
# 95             NaN    6.0     1.0       2.0  121.407487  31.074013
# 96             NaN   18.0     2.0       4.0  121.371859  31.148492
# 97             NaN   28.0     1.0       2.0  121.387241  31.030584
# 98             NaN   11.0     1.0       2.0  121.341557  31.159538
# 99             NaN    4.0     1.0       2.0  121.500610  31.110415
#
# [100 rows x 27 columns]

# %%
for i in range(len(data_preprocess.isnull().sum(1))):
    if data_preprocess.isnull().sum(1)[i] <= 1:
        print(i)
# Out:
# 27
# 51
# 55
# 76
# 87
# 94
# 95
# 97

# %%
ddd = {'1':[1,2], '2':[3,5]}
l = [1,2,3,4,5]
for k in ddd.keys():
    for feature in ddd[k]:
        if feature not in l[:3]:
            ddd[k].remove(feature)
print(ddd)
# Out:
# {'1': [1, 2], '2': [3]}

# %%
# cols

# %%
mpl.rcParams['font.sans-serif'] = ['SimHei']

input_path =  '../../../Data/Price_System/Price_Predict/preprocess/house/used_house_data_test_preprocess.csv'
output_path = '../../../Data/Price_System/Price_Predict/qualified/house/used_house_data_test_qualified.csv'
docs_path = '../../../docs/Price_System/Price_Predict/used_house_data_test/'
data_qualified = predict_qualified(input_path=input_path, 
                                   output_path=output_path,
                                   docs_path=docs_path,
                                   name_of_target='Final_Price', cols=cols)
data_qualified
# Out:
# 数据去重开始
# 去重后数据规格：(100, 27)
# 数据去重结束
# 去除了缺失率超过40 % 的特征:
# Property_Rights_Time
# Year_Of_Housing
# 数值型数据EM插补开始,总数据量：100
# 数值型数据EM插补完成，耗时0秒
# 非数值型数据EM插补开始,总数据量：100
# 分类变量预编码完成，开始数据插值
# 分类变量插值与反编码完成，共耗时0秒
# 异常检测开始
# All-NaN slice encountered
# All-NaN slice encountered
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Iteration num: 3
# =========异常点作图========
# 异常检测数： 12
# 异常检测后数据规格：(100, 14)
# 耗时：11.3148
# 异常检测结束
#    House_Type  Final_Price  Transaction_Cycle  Num_Price_Adjustment  Num_Look  \
# 0        1室1厅        218.0           0.857895                   0.0      0.25
# 1        2室1厅        368.0          -0.257895                   0.0     -0.50
# 2        3室2厅        775.0           0.942105                   0.0     -0.25
# 3        1室1厅        219.0           5.415789                   0.0     -0.75
# 4        3室2厅        331.0          -0.426316                   0.0     -0.50
# ..        ...          ...                ...                   ...       ...
# 83       2室1厅        220.0           3.015789                   0.0      0.25
# 84       3室2厅        878.0           0.015789                   0.0     -0.75
# 85       2室2厅        371.0          -0.205263                   0.0     -0.50
# 86       3室2厅        850.0           0.005263                   0.0      0.25
# 87       2室2厅        550.0           0.089474                   0.0     -0.50
#
#     Attention  Num_Browse Floor  Construction_Area Unit_Structure  ...  \
# 0   -0.467153   -0.069801     中          -0.598802             平层  ...
# 1   -0.729927    1.300495     低          -0.287425             平层  ...
# 2    0.642336    1.010996     高           1.365269             跃层  ...
# 3    0.934307    0.831554     低          -0.526946             平层  ...
# 4   -0.204380   -0.191235     中           1.269461             平层  ...
# ..        ...         ...   ...                ...            ...  ...
# 83   0.350365    1.138167     低          -0.119760             平层  ...
# 84  -0.408759   -0.218327     低           1.461078             平层  ...
# 85  -0.175182   -0.107729     高           0.143713             平层  ...
# 86  -0.700730   -0.379920     低           1.389222             平层  ...
# 87  -0.583942   -0.484143     低           0.694611             平层  ...
#
#    Ladder_Ratio Elevator  Trading_Authority Housing_Purposes House_Ownership  \
# 0          一梯六户        有              动迁安置房             普通住宅             非共有
# 1          一梯四户        无                商品房             普通住宅             非共有
# 2          一梯两户        有                商品房             普通住宅              共有
# 3          一梯两户        无                商品房             普通住宅              共有
# 4          一梯两户        有                商品房             普通住宅              共有
# ..          ...      ...                ...              ...             ...
# 83         一梯两户        无                商品房             普通住宅              共有
# 84         两梯四户        有                商品房             普通住宅             非共有
# 85         一梯两户        有                商品房             普通住宅             非共有
# 86         一梯两户        有                商品房             普通住宅              共有
# 87         一梯两户        无                商品房             普通住宅             非共有
#
#       Storey Ladder Household Longitude  Latitude
# 0   3.666667    0.0       2.0  0.000000 -0.313916
# 1   0.000000    0.0       1.0 -0.061210  0.248466
# 2   0.833333    0.0       0.0  1.699470 -1.836695
# 3   0.000000    0.0       0.0  0.965700  1.236229
# 4   1.000000    0.0       0.0  1.150993  0.334930
# ..       ...    ...       ...       ...       ...
# 83  0.000000    0.0       0.0 -0.647327 -0.941570
# 84  2.000000    1.0       1.0 -0.862609 -0.158236
# 85  3.666667    0.0       0.0 -0.769663 -1.398335
# 86  0.833333    0.0       0.0 -1.045708 -0.042060
# 87 -0.333333    0.0       0.0 -0.084631 -0.558711
#
# [88 rows x 25 columns]

# %%
input_path='../../../Data/Price_System/Price_Predict/qualified/house/used_house_data_test_qualified.csv'
output_path='../../../Data/Price_System/Price_Predict/encoding/house/used_house_data_test_encoding.csv'
data_encoding = predict_encoding(input_path=input_path,
                                 output_path=output_path,
                                 cols=cols,
                                 name_of_target='Final_Price',
                                 type_of_encoding='target')
data_encoding
# Out:
# 数据编码开始
# 编码后数据规格：(88, 25)
# 耗时：0.0586
# 数据编码结束
#     House_Type  Final_Price  Transaction_Cycle  Num_Price_Adjustment  \
# 0   328.540264        218.0           0.857895                   0.0
# 1   332.343892        368.0          -0.257895                   0.0
# 2   346.415481        775.0           0.942105                   0.0
# 3   328.540264        219.0           5.415789                   0.0
# 4   346.415481        331.0          -0.426316                   0.0
# ..         ...          ...                ...                   ...
# 83  332.343892        220.0           3.015789                   0.0
# 84  346.415481        878.0           0.015789                   0.0
# 85  339.434924        371.0          -0.205263                   0.0
# 86  346.415481        850.0           0.005263                   0.0
# 87  339.434924        550.0           0.089474                   0.0
#
#     Num_Look  Attention  Num_Browse       Floor  Construction_Area  \
# 0       0.25  -0.467153   -0.069801  332.542562          -0.598802
# 1      -0.50  -0.729927    1.300495  337.177314          -0.287425
# 2      -0.25   0.642336    1.010996  338.477063           1.365269
# 3      -0.75   0.934307    0.831554  337.177314          -0.526946
# 4      -0.50  -0.204380   -0.191235  332.542562           1.269461
# ..       ...        ...         ...         ...                ...
# 83      0.25   0.350365    1.138167  337.177314          -0.119760
# 84     -0.75  -0.408759   -0.218327  337.177314           1.461078
# 85     -0.50  -0.175182   -0.107729  338.477063           0.143713
# 86      0.25  -0.700730   -0.379920  337.177314           1.389222
# 87     -0.50  -0.583942   -0.484143  337.177314           0.694611
#
#     Unit_Structure  ...  Ladder_Ratio    Elevator  Trading_Authority  \
# 0       335.246232  ...    335.664603  343.352722         333.902428
# 1       335.246232  ...    329.360644  329.370600         338.234330
# 2       337.515101  ...    339.294416  343.352722         338.234330
# 3       335.246232  ...    339.294416  329.370600         338.234330
# 4       335.246232  ...    339.294416  343.352722         338.234330
# ..             ...  ...           ...         ...                ...
# 83      335.246232  ...    339.294416  329.370600         338.234330
# 84      335.246232  ...    338.172336  343.352722         338.234330
# 85      335.246232  ...    339.294416  343.352722         338.234330
# 86      335.246232  ...    339.294416  343.352722         338.234330
# 87      335.246232  ...    339.294416  329.370600         338.234330
#
#     Housing_Purposes  House_Ownership    Storey  Ladder  Household  Longitude  \
# 0         336.056818       332.668719  3.666667     0.0        2.0   0.000000
# 1         336.056818       332.668719  0.000000     0.0        1.0  -0.061210
# 2         336.056818       339.504532  0.833333     0.0        0.0   1.699470
# 3         336.056818       339.504532  0.000000     0.0        0.0   0.965700
# 4         336.056818       339.504532  1.000000     0.0        0.0   1.150993
# ..               ...              ...       ...     ...        ...        ...
# 83        336.056818       339.504532  0.000000     0.0        0.0  -0.647327
# 84        336.056818       332.668719  2.000000     1.0        1.0  -0.862609
# 85        336.056818       332.668719  3.666667     0.0        0.0  -0.769663
# 86        336.056818       339.504532  0.833333     0.0        0.0  -1.045708
# 87        336.056818       332.668719 -0.333333     0.0        0.0  -0.084631
#
#     Latitude
# 0  -0.313916
# 1   0.248466
# 2  -1.836695
# 3   1.236229
# 4   0.334930
# ..       ...
# 83 -0.941570
# 84 -0.158236
# 85 -1.398335
# 86 -0.042060
# 87 -0.558711
#
# [88 rows x 25 columns]

# %%
# data_encoding.isnull().sum()

# %%
input_path='../../../Data/Price_System/Price_Predict/encoding/house/used_house_data_test_encoding.csv'
output_path='../../../Data/Price_System/Price_Predict/feature/house/used_house_data_test_feature.csv'
feature_path='../../../output/Price_System/Price_Predict/results/feature_test.txt'
data_feature = predict_feature(input_path=input_path,
                               output_path=output_path,
                               feature_path=feature_path,
                               num_of_feature=15, name_of_target='Final_Price')
data_feature
# Out:
#     House_Type  Final_Price  Transaction_Cycle  Num_Look  Attention  \
# 0   328.540264        218.0           0.857895      0.25  -0.467153
# 1   332.343892        368.0          -0.257895     -0.50  -0.729927
# 2   346.415481        775.0           0.942105     -0.25   0.642336
# 3   328.540264        219.0           5.415789     -0.75   0.934307
# 4   346.415481        331.0          -0.426316     -0.50  -0.204380
# ..         ...          ...                ...       ...        ...
# 83  332.343892        220.0           3.015789      0.25   0.350365
# 84  346.415481        878.0           0.015789     -0.75  -0.408759
# 85  339.434924        371.0          -0.205263     -0.50  -0.175182
# 86  346.415481        850.0           0.005263      0.25  -0.700730
# 87  339.434924        550.0           0.089474     -0.50  -0.583942
#
#          Floor  Construction_Area    Oriented       Age  Renovation  \
# 0   332.542562          -0.598802  332.223216  0.875000  334.278778
# 1   337.177314          -0.287425  332.223216 -1.375000  342.783518
# 2   338.477063           1.365269  332.223216 -0.041667  332.962758
# 3   337.177314          -0.526946  332.223216  0.208333  342.783518
# 4   332.542562           1.269461  332.223216  0.708333  334.278778
# ..         ...                ...         ...       ...         ...
# 83  337.177314          -0.119760  332.223216 -0.625000  333.778650
# 84  337.177314           1.461078  332.223216  0.458333  342.783518
# 85  338.477063           0.143713  332.223216  1.041667  334.278778
# 86  337.177314           1.389222  332.223216  0.625000  342.783518
# 87  337.177314           0.694611  340.029657  0.291667  342.783518
#
#     Construction_struct  Ladder_Ratio    Elevator  Trading_Authority  \
# 0            344.979724    335.664603  343.352722         333.902428
# 1            327.185639    329.360644  329.370600         338.234330
# 2            344.979724    339.294416  343.352722         338.234330
# 3            344.979724    339.294416  329.370600         338.234330
# 4            344.979724    339.294416  343.352722         338.234330
# ..                  ...           ...         ...                ...
# 83           327.185639    339.294416  329.370600         338.234330
# 84           344.979724    338.172336  343.352722         338.234330
# 85           344.979724    339.294416  343.352722         338.234330
# 86           344.979724    339.294416  343.352722         338.234330
# 87           344.979724    339.294416  329.370600         338.234330
#
#     Longitude  Latitude
# 0    0.000000 -0.313916
# 1   -0.061210  0.248466
# 2    1.699470 -1.836695
# 3    0.965700  1.236229
# 4    1.150993  0.334930
# ..        ...       ...
# 83  -0.647327 -0.941570
# 84  -0.862609 -0.158236
# 85  -0.769663 -1.398335
# 86  -1.045708 -0.042060
# 87  -0.084631 -0.558711
#
# [88 rows x 16 columns]

# %%
input_path = '../../../Data/Price_System/Price_Predict/feature/house/used_house_data_test_feature.csv'
model_path = '../../../output/Price_System/Price_Predict/model/price_predict_test_bagging.pkl'
train, test_result, train_X, test_X, test_y =  predict_model(input_path=input_path,
                                                             model_path = model_path,                                                             
                                                             name_of_model='bagging',
                                                             name_of_target='Final_Price')
train
# Out:
# BaggingRegressor(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                  max_features=1.0, max_samples=1.0, n_estimators=10,
#                  n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                  warm_start=False)

# %%
train_X.to_csv('../../../output/Price_System/Price_Predict/results/bagging_test_train_X.csv' ,index=False)
train_X
# Out:
#     House_Type  Transaction_Cycle  Num_Look  Attention       Floor  \
# 0   328.540264           0.857895      0.25  -0.467153  332.542562
# 1   332.343892          -0.257895     -0.50  -0.729927  337.177314
# 2   346.415481           0.942105     -0.25   0.642336  338.477063
# 3   328.540264           5.415789     -0.75   0.934307  337.177314
# 4   346.415481          -0.426316     -0.50  -0.204380  332.542562
# ..         ...                ...       ...        ...         ...
# 66  346.415481           0.647368     -0.75  -0.029197  337.177314
# 67  332.343892          -0.373684      0.25  -0.379562  337.177314
# 68  332.343892           2.542105     -0.25   0.437956  338.477063
# 69  339.434924          -0.615789     -0.50  -0.700730  337.177314
# 70  339.434924          -0.573684      0.25   0.437956  337.177314
#
#     Construction_Area    Oriented       Age  Renovation  Construction_struct  \
# 0           -0.598802  332.223216  0.875000  334.278778           344.979724
# 1           -0.287425  332.223216 -1.375000  342.783518           327.185639
# 2            1.365269  332.223216 -0.041667  332.962758           344.979724
# 3           -0.526946  332.223216  0.208333  342.783518           344.979724
# 4            1.269461  332.223216  0.708333  334.278778           344.979724
# ..                ...         ...       ...         ...                  ...
# 66           1.485030  340.029657  0.541667  332.962758           344.979724
# 67          -0.479042  332.223216 -1.208333  342.783518           327.185639
# 68          -0.167665  332.223216 -0.708333  342.783518           327.185639
# 69           0.383234  332.223216  0.041667  332.962758           344.979724
# 70           0.407186  332.223216  0.125000  332.962758           344.979724
#
#     Ladder_Ratio    Elevator  Trading_Authority  Longitude  Latitude
# 0     335.664603  343.352722         333.902428   0.000000 -0.313916
# 1     329.360644  329.370600         338.234330  -0.061210  0.248466
# 2     339.294416  343.352722         338.234330   1.699470 -1.836695
# 3     339.294416  329.370600         338.234330   0.965700  1.236229
# 4     339.294416  343.352722         338.234330   1.150993  0.334930
# ..           ...         ...                ...        ...       ...
# 66    339.294416  329.370600         338.234330  -0.602522 -1.519634
# 67    339.294416  329.370600         338.234330  -0.638994 -1.533517
# 68    339.294416  329.370600         338.234330  -0.660046 -0.028502
# 69    339.294416  329.370600         338.234330  -0.248661 -1.265646
# 70    335.440277  343.352722         338.234330  -0.627803 -0.297625
#
# [71 rows x 15 columns]

# %%
model_path = '../../../output/Price_System/Price_Predict/model/price_predict_test_bagging.pkl'
data_path = '../../../Data/Price_System/Price_Predict/feature/house/used_house_data_test_feature.csv'
result = predict_prediction(model_path=model_path,
                            data_path=data_path,
                            name_of_target='Final_Price')
result
# Out:
# array([222.4, 391.1, 665.2, 219.4, 272.2, 337.3, 313. , 187.3, 268.3,
#        577.6, 199.9, 353.9, 446.5, 284.4, 202.5, 458.6, 305.9, 227. ,
#        325.6, 232. , 202.9, 281.5, 296.9,  63.2, 255. , 541. , 267.4,
#        317.4, 293.1, 364.6, 245.8, 416.2, 424.1, 650.1, 280.5, 296.4,
#        208.5, 411.2, 148. , 230.1, 330.6, 225.9, 234.4,  88.1, 213.5,
#        410.7, 395.7, 230. , 434.6, 348.2, 714.5, 512.5, 247.7, 270.4,
#        576.8, 628.7, 260.5, 270.6, 235.5, 373.6, 222.2, 255.7, 623.1,
#        334.7, 480.5, 247.6, 597.3, 207.1, 337.9, 380.5, 461. , 243.8,
#        285.1, 262.6, 547.2, 529.1, 556.8, 316.9, 303.2, 190.5, 228.8,
#        369.5, 268.8, 246.9, 533.9, 342.8, 524.6, 632. ])

# %%
[round(result[i] / data_feature['Final_Price'].values[i], 2) for i in range(len(data_feature['Final_Price'].values))]
# for i in range(len(data_feature['Final_Price'].values)):
#     print(round(result[i] / data_feature['Final_Price'].values[i], 2))
# Out:
# [1.02,
#  1.06,
#  0.86,
#  1.0,
#  0.82,
#  0.82,
#  1.0,
#  0.96,
#  1.12,
#  1.14,
#  1.05,
#  0.99,
#  0.96,
#  1.6,
#  1.0,
#  0.9,
#  1.01,
#  1.07,
#  1.0,
#  1.0,
#  0.97,
#  1.08,
#  1.0,
#  15.8,
#  1.01,
#  0.96,
#  1.19,
#  0.96,
#  1.22,
#  1.04,
#  1.05,
#  1.0,
#  0.98,
#  0.87,
#  0.94,
#  1.29,
#  1.19,
#  0.78,
#  0.9,
#  1.05,
#  0.96,
#  0.87,
#  0.92,
#  17.62,
#  1.26,
#  0.92,
#  0.95,
#  1.21,
#  0.98,
#  69.64,
#  0.88,
#  0.92,
#  1.13,
#  1.35,
#  0.96,
#  0.9,
#  1.12,
#  0.8,
#  1.12,
#  1.33,
#  1.13,
#  1.03,
#  0.81,
#  1.03,
#  0.9,
#  1.24,
#  1.12,
#  1.21,
#  0.9,
#  1.29,
#  0.84,
#  1.5,
#  1.16,
#  1.37,
#  1.27,
#  1.53,
#  1.34,
#  1.38,
#  60.64,
#  1.09,
#  0.77,
#  1.09,
#  1.08,
#  1.12,
#  0.61,
#  0.92,
#  0.62,
#  1.15]

# %%
name_of_model = 'bagging'
model_path = '../../../output/Price_System/Price_Predict/model/price_predict_test_bagging.pkl'
data_path = '../../../output/Price_System/Price_Predict/results/bagging_test_train_X.csv'
output_path = '../../../output/Price_System/Price_Predict/analysis/bagging_test_shap.png'
predict_analysis(model_path=model_path,
                 name_of_model=name_of_model,
                 data_path=data_path,
                 output_path=output_path)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=71.0), HTML(value='')))

# %%
# input_path = '../../../Data/Price_System/Price_Predict/feature/house/used_house_data_feature.csv'
# model_path = '../../../output/Price_System/Price_Predict/model/price_predict_xgboost.pkl'
# train, test_result, train_X, test_X, test_y =  predict_model(input_path=input_path,
#                                                              model_path = model_path,                                                             
#                                                              name_of_model='xgboost',
#                                                              name_of_target='Final_Price')
# train
# Out:
# XGBRegressor(alpha=0, base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eta=0.3, gamma=0,
#              gpu_id=-1, importance_type='gain', interaction_constraints=None,
#              lambda_=1, learning_rate=0.300000012, max_bin=256,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints=None, n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, objective='reg:squarederror', random_state=0,
#              refresh_leaf=1, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              sketch_eps=0.03, ...)

# %%
# train_X.to_csv('../../../output/Price_System/Price_Predict/results/xgboost_train_X.csv',index=False)
# train_X
# Out:
#        House_Type  Transaction_Cycle  Num_Look  Attention  Construction_Area  \
# 0      229.628784          -0.061709  0.571429   0.125000          -0.488372
# 1      653.252701          -0.284810  0.571429   0.083333           1.930233
# 2      294.769983          -0.229430  0.142857  -0.250000          -0.186047
# 3      479.571491          -0.131329  2.571429   6.708333           0.511628
# 4      653.252701          -0.049051  0.285714   1.708333           1.418605
# ...           ...                ...       ...        ...                ...
# 40856  768.717020          -0.136076  2.714286   0.916667           1.720930
# 40857  294.769983          -0.243671  0.714286   1.000000          -0.418605
# 40858  294.769983           0.007911  2.857143   3.916667          -0.348837
# 40859  229.628784          -0.221519  0.142857  -0.083333          -0.627907
# 40860  294.769983          -0.245253  1.000000   0.166667          -0.348837
#
#        Type_Structure       Age  Renovation  Ladder_Ratio  Trading_Authority  \
# 0          458.303994  1.066667  379.977667    259.135624         281.665441
# 1          365.879921  0.533333  302.797439    884.343793         382.279302
# 2          365.879921 -0.733333  425.808158    251.878734         382.279302
# 3          365.879921  0.933333  379.977667    548.041994         382.279302
# 4          365.879921  0.333333  302.797439    365.531627         382.279302
# ...               ...       ...         ...           ...                ...
# 40856      365.879921  0.400000  425.808158    365.531627         382.279302
# 40857      365.879921 -1.000000  425.808158    251.878734         382.279302
# 40858      365.879921 -0.733333  425.808158    251.878734         382.279302
# 40859      365.879921 -0.800000  302.797439    251.878734         382.279302
# 40860      365.879921 -0.133333  425.808158    251.878734         382.279302
#
#          Storey  Ladder  Household  Longitude  Latitude
# 0      2.000000     0.0        1.0   0.635657 -0.893918
# 1      2.363636     1.0       -1.0   0.931001 -0.024004
# 2      0.000000     0.0        0.0   0.538632 -0.434527
# 3      1.090909     1.0        0.0   1.418047 -0.993767
# 4      0.454545     0.0       -1.0   3.329470 -2.137823
# ...         ...     ...        ...        ...       ...
# 40856  1.090909     0.0       -1.0  -0.218865  0.010619
# 40857  0.090909     0.0        0.0  -0.264829  0.060518
# 40858  0.000000     0.0        0.0   0.021253  0.255603
# 40859  0.000000     0.0        0.0  -0.381028  0.246951
# 40860  0.000000     0.0        0.0  -0.847596  0.471848
#
# [40861 rows x 15 columns]

# %%
# model_path = '../../../output/Price_System/Price_Predict/model/price_predict_xgboost.pkl'
# data_path = '../../../Data/Price_System/Price_Predict/feature/house/used_house_data_feature.csv'
# result = predict_prediction(model_path=model_path,
#                             data_path=data_path,
#                             name_of_target='Final_Price')
# result
# Out:
# array([ 163.97755, 1607.4213 ,  310.15894, ...,  181.72508,  148.2515 ,
#         138.63252], dtype=float32)

# %%
# name_of_model = 'xgboost'
# model_path = '../../../output/Price_System/Price_Predict/model/price_predict_xgboost.pkl'
# data_path = '../../../output/Price_System/Price_Predict/results/xgboost_train_X.csv'
# output_path = '../../../output/Price_System/Price_Predict/analysis/xgboost_shap.png'
# predict_analysis(model_path=model_path,
#                  name_of_model=name_of_model,
#                  data_path=data_path,
#                  output_path=output_path)

# %%
fw = open(path_stand_feature, 'w', encoding='UTF-8')
for i in ['sss','s']:
    fw.write(i + '\n')
fw.close()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/zhangjianquan/anaconda3/envs/python/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-94-2e2fed6fce41>", line 1, in <module>
#     fw = open(path_stand_feature, 'w', encoding='UTF-8')
# FileNotFoundError: [Errno 2] No such file or directory: 'a.txt'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/zhangjianquan/anaconda3/envs/python/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/zhangjianquan/anaconda3/envs/python/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/zhangjianquan/anaconda3/envs/python/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/home/zhangjianquan/anaconda3/envs/python/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/zhangjianquan/anaconda3/envs/python/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/zhangjianquan/anaconda3/envs/python/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/zhangjianquan/anaconda3/envs/python/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/zhangjianquan/anaconda3/envs/python/lib/python3.7/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/home/zhangjianquan/anaconda3/envs/python/lib/python3.7/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/zhangjianquan/anaconda3/envs/python/lib/python3.7/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------

# %%
# data_path = '../../../Data/Price_System/Price_Predict/raw/house/used_house_data_test.csv'

# %%
# model_path = '../../../output/Price_System/Price_Predict/model/price_predict_xgboost.pkl'
# # data_path = '../../../Data/Price_System/Price_Predict/raw/house/used_house_data_test.csv'
# # data_path = '../../../Data/Price_System/Price_Predict/preprocess/house/used_house_data_test_preprocess.csv'
# # data_path = '../../../Data/Price_System/Price_Predict/qualified/house/used_house_data_test_qualified.csv'
# # data_path = '../../../Data/Price_System/Price_Predict/encoding/house/used_house_data_test_encoding.csv'
# data_path = '../../../Data/Price_System/Price_Predict/feature/house/used_house_data_test_feature.csv'
# result = predict_prediction(model_path=model_path,
#                             data_path=data_path,
#                             name_of_target='Final_Price')
# result
